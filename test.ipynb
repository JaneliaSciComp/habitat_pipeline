# %%
from ingestion.kilosort_paths import get_kilosort_path, verify_kilosort_path
import importlib
# Out:
# False

# %%
importlib.reload(importlib.import_module("ingestion.kilosort_paths"))
path1 = get_kilosort_path("613", "20251210")           # Partial matching
path1.exists()


verify_kilosort_path(path1)
# Out:
# c:\Users\proskurinm\GitHub\habitat_pipeline\ingestion\kilosort_paths.py:16: SyntaxWarning: invalid escape sequence '\k'
#   """
# False
